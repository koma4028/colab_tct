# %%
# 이 파일은 제대로 인식되는지 한번 보자

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/GitHub_Commit/colab_tct
# Out:
# /content/drive/MyDrive/Colab Notebooks/GitHub_Commit/colab_tct

# %%
# !git config --global user.email 'koma4028@gmail.com'
# !git config --global user.name 'koma4028'

# %%
# !git add test_code_2.ipynb

# %%
# !git commit -m 'Second Test'
# !git push
# Out:
# [main ead809d] Second Test
#  1 file changed, 1 insertion(+)
#  create mode 100644 test_code_2.ipynb
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.17 KiB | 398.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/koma4028/colab_tct.git
#    29ee558..ead809d  main -> main
